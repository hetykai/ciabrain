# %%
#内置图像，引入R语言
# %matplotlib inline
# %config InlineBackend.figure_format="svg"
# %load_ext rpy2.ipython

# %% [markdown]
# # 1.一个演示会话

# %%
# %%R
# #产生两个伪正态随机数向量x和y
# x<-rnorm(50)
# y<-rnorm(x)
# plot(x,y)#画出散点图
# ls()#查看当前操作空间的R对象
# rm(x,y)#去掉不在需要的对象
# x<-1:20#创建一个连续变量
# w<-1+sqrt(x)/2#
