# %%
#内置图像，引入R语言
# %matplotlib inline
# %config InlineBackend.figure_format="svg"
# %load_ext rpy2.ipython

# %%
# %%R
# library(TSA)

# %%
# %%R  -w 1000 -h 300
# data(larain);plot(larain,ylab = 'Inches',xlab = 'Year',type = 'o')
# plot(y = larain,x=zlag(larain),ylab = 'Inches',xlab='Previous')

# %%
# %%R  -w 400 -h 400
# #画出时间序列散点图
# plot(y = larain,x=zlag(larain),ylab = 'Inches',xlab='Previous')
